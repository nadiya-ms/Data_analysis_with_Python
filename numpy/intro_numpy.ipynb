# %% [markdown]
# Introduction to Ndarrays

# %%
import numpy as np

# %%
data_ndarray_1 = np.array([5, 10, 15, 20])
data_ndarray_2 = np.array([10, 20, 30])

# %% [markdown]
# Array Shapes

# %%
import csv
import numpy as np

# import nyc_taxi.csv as a list of lists
f = open("C:\\Users\\zahn\\workspace\\Python_scripts\\data_files\\nyc_taxis.csv", "r")
taxi_list = list(csv.reader(f))

# remove the header row
taxi_list = taxi_list[1:]

# convert all values to floats
converted_taxi_list = []
for row in taxi_list:
    converted_row = []
    for element in row:
        converted_row.append(float(element))
    converted_taxi_list.append(converted_row)

# start writing your code below this comment
taxi = np.array(converted_taxi_list)

# %%
print(taxi)
# Out:
# [[2.016e+03 1.000e+00 1.000e+00 ... 1.165e+01 6.999e+01 1.000e+00]
#  [2.016e+03 1.000e+00 1.000e+00 ... 8.000e+00 5.430e+01 1.000e+00]
#  [2.016e+03 1.000e+00 1.000e+00 ... 0.000e+00 3.780e+01 2.000e+00]
#  ...
#  [2.016e+03 6.000e+00 3.000e+01 ... 5.000e+00 6.334e+01 1.000e+00]
#  [2.016e+03 6.000e+00 3.000e+01 ... 8.950e+00 4.475e+01 1.000e+00]
#  [2.016e+03 6.000e+00 3.000e+01 ... 0.000e+00 5.484e+01 2.000e+00]]

# %%
data_ndarray = np.array([[5, 10, 15], 
                         [20, 25, 30]])
print(data_ndarray.shape)
# Out:
# (2, 3)

# %%
taxi_shape=taxi.shape
print(taxi_shape)
# Out:
# (89560, 15)

# %% [markdown]
# Selecting and Slicing Rows from Ndarrays

# %%
row_0 = taxi[0]
rows_391_to_500 = taxi[391:501]
row_21_column_5 = taxi[21,5]

# %% [markdown]
# Selecting Columns and Custom Slicing Ndarrays

# %%
columns_1_4_7 = taxi[:,[1,4,7]]
row_99_columns_5_to_8 = taxi[99,5:9]
rows_100_to_200_column_14 = taxi[100:201, 14]

# %% [markdown]
# Vector Operations

# %%
fare_amount = taxi[:,9]
fees_amount = taxi[:,10]
fare_and_fees = fare_amount + fees_amount
print(fare_and_fees)
